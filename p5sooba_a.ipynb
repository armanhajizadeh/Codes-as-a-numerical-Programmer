# %%
import pandas as pd
import numpy as np
import datetime
import random
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.signal import find_peaks


random.seed(5)
signup_datetime = datetime.datetime.today()
signup_datetimes = []
total_signups = 2000

for signup in range(total_signups):
    signup_datetime = signup_datetime + datetime.timedelta(days=1)
    signup_datetimes.append(signup_datetime)
    
df = pd.DataFrame({'user_created_at': signup_datetimes})
df['A'] = np.random.uniform(1, 10, df.shape[0])
df['Date'] = df['user_created_at'].dt.strftime('%Y-%m-%d')
df.drop('user_created_at', inplace=True, axis=1)
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=200)
df['B'] = df.rolling(window=indexer, min_periods=1).median()
df["A"].plot()
df["B"].plot()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15904\2969298310.py:24: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   df['B'] = df.rolling(window=indexer, min_periods=1).median()
